# %% [markdown]
# ---
# numbering:
#   title:
#     offset: 1
# ---

# %% [markdown]
# (ch13.2)=
# # Tail Bounds

# %% [markdown]
# %% motivate tail bound problem in setting of showing consistency
#
# %% tail bound problem

# %% [markdown]
# %% Markov
#
# %% Chebyshev

# %% [markdown]
# %% Applications to give finite sample guarantees on error (probabilistic bounds on errors)
