# %% [markdown]
# ---
# numbering:
#   title:
#     offset: 1
# ---

# %% [markdown]
# (ch9.2)=
# # Gradients

# %% [markdown]
# # Gradients
#
# ## Examples
#
# ## Linearization via Gradients
#
# # Directional Derivatives
#
# ## Examples
#
# # Gradient Geometry
#
# ## Fastest Ascent
#
# ## Level Sets and Gradients
