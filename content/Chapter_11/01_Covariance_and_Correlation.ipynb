# %% [markdown]
# ---
# numbering:
#   title:
#     offset: 1
# ---

# %% [markdown]
# (ch11.1)=
# # Covariance and Correlation
#
# ## Objectives
#
# % how related are X and Y?
#
# % provide bivariate normal density as an example
#
# % desiderata
#
# % 1. interpretable sign and magnitude, ideally bounded
# % 2. independent of translations
# % 3. independent of scaling - motivate with unit change and with axis zoom changes

# %% [markdown]
# ## Covariance
#
# % center to achieve (2)
#
# % idea of "covarying" with quadrants picture
#
# % pay more attention to large variations than small variations
#
# % show achieved by the product of deviations
#
# % average over the joint to define covariance
#
# % compare to variance, show variance is a special case of covariance
#
# % define a covariance matrix as a way of arranging/storing covariances
#
# % show that it depends on scale

# %% [markdown]
# ## Correlation
#
# % standard units for scale invariance
#
# % standardized variable
#
# % define correlation as covariance in standardized variables
#
# % derive direct equation - show scale and center invariant
#
# % link to interactive to guess correlation
#
# % state bounds (+- 1, linear relation if +- 1)

# %% [markdown]
# ## Correlation and Dependence
#
# % show correlation and covariance  = 0 if independent
#
# % covariance = 0  and correlation = 0 does not mean independent (X example and O example)
#
# % exceptions to the rule: indicators, normals
