# %% [markdown]
# ---
# numbering:
#   title:
#     offset: 1
# ---

# %% [markdown]
# (chA.4)=
# # Demos Glossary
#
# ## Chapter 1 - Probability Fundamentals
#
# ## Chapter 2 - Random Variables and Distribution Functions
#
# 1. [Distribution Plotter](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=lab%2Ftree%2FDATA-89%2Fweek_2_dist_models.ipynb). This is the tool used in [Sections 2.2](#ch2.2) and [2.4](#ch2.4) to visualized PMFs and PDFs. You will need it for your first HW. It is a good reference to come back to throughout the course. I suggest you bookmark it.
#
# 1. [Dartboard Sampler](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=lab%2Ftree%2FDATA-89%2Fweek_2_dartboard.ipynb) - This is the example used in [Section 2.3](*ch2.3) to derive the idea of a density function.
#
# 1. [PMF, PDF, CDF Explorer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fdata-89-berkeley%2Fnotes&branch=main&urlpath=lab%2Ftree%2Fnotes%2Fcontent%2FChapter_02%2Fweek_3_pdf_to_cdf.ipynb ) -This the tool used in [Sections 2.1](#ch2.1), [2.2](#ch2.2) and [2.4](#ch2.4) tp visualize the relationship between the PMF, CDF, and PDF.
#
# ## Chapter 3 - Visualizing Functions and Models
#
# 1. [Function Properties and Linear Transformations](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Ffunction_properties.ipynb) - Use this tool to visualize linear transformations of functions (inputs and outputs) and to check your understanding of key global properties.
#
# 1. [Function Combination](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Ffunction_inverse.ipynb) - Use this tool to visualize linear combinations and products of functions.
#
# 1. [Function Composition I - 2D](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Ffunction_composition.ipynb) - Use this tool to visualize function compositions.
#
# 1. [Function Composition II - 3D](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Fcomposite_functions_week_4.ipynb) - Use this tool to visualize function compositions in three dimensions. It works best when the outer function is monotonic and bounded.
#
# 1. [Function Inversion](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Ffunction_inverse.ipynb) - Use this tool to visualize function inverses.
#
# ## Chapter 4 - Summarizing Distributions with Expectations
#
# 1. [Expectation and Variance Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Fexp_std_stand_demo.ipynb) - Use this tool to visualize the median, expected value, standard deviation, and mean absolute deviation in a variety of random variables.
#
# 1. [Law of Large Numbers Interactive](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=lab%2Ftree%2FDATA-89%2Flarge_numbers.ipynb) - Use this interactive to watch sample averages over large data sets converge to expectations.
#
#
# ## Chapter 5 - Comparing Tails
#
# 1. [Tail Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2F5_1_demo.ipynb) - Use this tool to visualize tails on log scales.
#
# ## Chapter 6 - Function Approximation
#
# 1. [Taylor Series Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=lab%2Ftree%2FDATA-89%2Fbenjamin%28taylor%29%2Ftaylor_demo.ipynb) - Use this tool to visualize Taylor series.
#
# ## Chapter 7 - Integration Techniques
#
# 1. [Change of Density Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Fchange_of_density.ipynb) - Use this tool to visualize changes of density.
#
# ## Chapter 8 - Random Vectors
#
# 1. [Surface Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Flevel_sets.ipynb) - Use this tool to visualize surfaces.
#
# 1. [Probability as Volume Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2[…]Ftree%2FDATA-89%2Fbenjamin%2Fjoint_distribution_demo.ipynb) - Use this tool to visualize probabilities as volumes under a joint distribution.
#
# ## Chapter 9 - Derivatives of Multivariate Functions
#
# 1. [Gradient Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Fgradient_vector_field.ipynb) - Use this tool to visualize the gradient vector fields associated with a surface.
#
# 1. [Gradient Ascent Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=lab%2Ftree%2FDATA-89%2Fgradient_ascent.ipynb). - Use this tool to visualize gradient ascent on the same surfaces provided in the Gradient Visualizer.
#
# 1. [Least Squares Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Fleast_squares.ipynb) - Use this tool to visualize the mean square error objective function used in least squares regression.
#
# # Chapter 10 - Integrals of Multivariate Functions
#
# 1. [Probability as Volume Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=lab%2Ftree%2FDATA-89%2Fbenjamin%2Fjoint_distribution_demo.ipynb) - Use this tool to visualize probabilities as volumes under a joint distribution.
#
# 1. [Conditional Expectation Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Fcond_exp.ipynb) - Use this tool to visualize conditional expectations.
#
# 1. [Convolution Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Fconvolution.ipynb) - Use this tool to visualize convolutions.
#
# # Chapter 11 - Measuring Association
#
# # Chapter 12 - Estimation
#
# # Chapter 13 - Concentration
#
# 1. [Law of Large Numbers Interactive](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=lab%2Ftree%2FDATA-89%2Flarge_numbers.ipynb) - Use this interactive to watch sample averages over large data sets converge to expectations.
#
# 1. [Convolution Visualizer](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=tree%2FDATA-89%2Fconvolution.ipynb) - Use this tool to visualize convolutions.
#
# 1. [Distribution Plotter](https://datahub.berkeley.edu/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fds-modules%2FDATA-89&branch=main&urlpath=lab%2Ftree%2FDATA-89%2Fweek_2_dist_models.ipynb). - Use this tool to visualize densities and to experiment with limiting distributions.
